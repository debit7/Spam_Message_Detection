# %%
import pandas as pd
with open('spam.data') as f:
        lst = []
        for ele in f:
            line = ele.replace('\n','').split('\t')
            
            lst.append(line)
Headers=['Classifier','Messages']
df = pd.DataFrame(lst,columns =Headers) 
df.head()
# Out:
#   Classifier                                           Messages
# 0        ham  Go until jurong point, crazy.. Available only ...
# 1        ham                      Ok lar... Joking wif u oni...
# 2       spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        ham  U dun say so early hor... U c already then say...
# 4        ham  Nah I don't think he goes to usf, he lives aro...

# %%
#randomly splitting data in training and testing data set
training = df.sample(frac=0.8)
test = df.drop(training.index)
#print(training)
print(test)
# Out:
#      Classifier                                           Messages
# 2          spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 6           ham  Even my brother is not like to speak with me. ...
# 7           ham  As per your request 'Melle Melle (Oru Minnamin...
# 15         spam  XXXMobileMovieClub: To use your credit, click ...
# 18          ham  Fine if that's the way u feel. That's the way ...
# ...         ...                                                ...
# 5556        ham  Well keep in mind I've only got enough gas for...
# 5562        ham                  Anything lor. Juz both of us lor.
# 5564        ham  Ok lor... Sony ericsson salesman... I ask shuh...
# 5568       spam  REMINDER FROM O2: To get 2.50 pounds free call...
# 5573        ham                         Rofl. Its true to its name
#
# [1115 rows x 2 columns]

# %%
#removing punctuations from the messages and converting the upper cases to lower case
punctuations='''€˜%^&"\,!*_~)(-[};:]{'<#£$>./?@'''
stop_words=["i","da","we","ur" ,"u","am","me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

for message in training['Messages']:
    
    print(message,'\n')
    for alpha in message:
        if alpha in punctuations:
            message = message.replace(alpha, " ")
    #for lower case        
    message=message.lower()
    
    #for stop words
    message=message.split()
    for word in message:
        if word in stop_words:
            print(word,'\n')
            message.remove(word)
    print(message,'\n')
    print(len(message),'\n')
# Out:
# Fine am simply sitting.
#
# am
#
# ['fine', 'simply', 'sitting']
#
# 3
#
# But we havent got da topic yet rite?
#
# but
#
# da
#
# ['we', 'havent', 'got', 'topic', 'yet', 'rite']
#
# 6
#
# U have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094599
#
# u
#
# a
#
# who
#
# with
#
# out
#
# they
#
# who
#
# ur
#
# on
#
# ['have', 'secret', 'admirer', 'is', 'looking', '2', 'make', 'contact', 'u', 'find', 'r', 'reveal', 'who', 'thinks', 'so', 'special', 'call', '09058094599']
#
# 18
#
# &lt;#&gt; %of pple marry with their lovers... becz they hav gud undrstndng dat avoids problems. i sent dis 2 u, u wil get gud news on friday by d person you like. And tomorrow will be the best day of your life. Dont break this chain. If you break you will suffer. send this to  &lt;#&gt;  frnds in &lt;#&gt;  mins whn u read...
#
# of
#
# with
#
# they
#
# i
#
# u
#
# on
#
# by
#
# you
#
# and
#
# will
#
# the
#
# of
#
# this
#
# if
#
# you
#
# this
#
# in
#
# u
#
# ['lt', 'gt', 'pple', 'marry', 'their', 'lovers', 'becz', 'hav', 'gud', 'undrstndng', 'dat', 'avoids', 'problems', 'sent', 'dis', '2', 'wil', 'get', 'gud', 'news', 'friday', 'd', 'person', 'like', 'tomorrow', 'be', 'best', 'day', 'your', 'life', 'dont', 'break', 'chain', 'break', 'you', 'will', 'suffer', 'send', 'to', 'lt', 'gt', 'frnds', 'lt', 'gt', 'mins', 'whn', 'u', 'read']
#
# 48
#
# Dear Sir,Salam Alaikkum.Pride and Pleasure meeting you today at the Tea Shop.We are pleased to send you our contact number at Qatar.Rakhesh an Indian.Pls save our Number.Respectful Regards.
#
# and
#
# you
#
# at
#
# we
#
# to
#
# you
#
# at
#
# an
#
# our
#
# ['dear', 'sir', 'salam', 'alaikkum', 'pride', 'pleasure', 'meeting', 'today', 'the', 'tea', 'shop', 'are', 'pleased', 'send', 'contact', 'number', 'qatar', 'rakhesh', 'indian', 'pls', 'save', 'our', 'number', 'respectful', 'regards']
#
# 25
#
# Nothin comes to my mind. Ãœ help me buy hanger lor. Ur laptop not heavy?
#
# to
#
# me
#
# ur
#
# not
#
# ['nothin', 'comes', 'my', 'mind', 'ãœ', 'help', 'buy', 'hanger', 'lor', 'laptop', 'heavy']
#
# 11
#
# Juz go google n search 4 qet...
#
# ['juz', 'go', 'google', 'n', 'search', '4', 'qet']
#
# 7
#
# I want  &lt;#&gt;  rs da:)do you have it?
#
# i
#
# da
#
# you
#
# it
#
# ['want', 'lt', 'gt', 'rs', 'do', 'have']
#
# 6
#
# A bit of Ur smile is my hppnss, a drop of Ur tear is my sorrow, a part of Ur heart is my life, a heart like mine wil care for U, forevr as my GOODFRIEND
#
# a
#
# of
#
# is
#
# a
#
# of
#
# is
#
# a
#
# of
#
# is
#
# a
#
# for
#
# as
#
# ['bit', 'ur', 'smile', 'my', 'hppnss', 'drop', 'ur', 'tear', 'my', 'sorrow', 'part', 'ur', 'heart', 'my', 'life', 'heart', 'like', 'mine', 'wil', 'care', 'u', 'forevr', 'my', 'goodfriend']
#
# 24
#
# Painful words- "I thought being Happy was the most toughest thing on Earth... But, the toughest is acting Happy with all unspoken pain inside.."
#
# i
#
# being
#
# was
#
# most
#
# on
#
# but
#
# is
#
# with
#
# ['painful', 'words', 'thought', 'happy', 'the', 'toughest', 'thing', 'earth', 'the', 'toughest', 'acting', 'happy', 'all', 'unspoken', 'pain', 'inside']
#
# 16
#
# Thanks, I'll keep that in mind
#
# i
#
# that
#
# ['thanks', 'll', 'keep', 'in', 'mind']
#
# 5
#
# Derp. Which is worse, a dude who always wants to party or a dude who files a complaint about the three drug abusers he lives with
#
# which
#
# a
#
# who
#
# to
#
# or
#
# who
#
# a
#
# about
#
# he
#
# with
#
# ['derp', 'is', 'worse', 'dude', 'always', 'wants', 'party', 'dude', 'files', 'a', 'complaint', 'the', 'three', 'drug', 'abusers', 'lives']
#
# 16
#
# Why she wants to talk to me
#
# why
#
# to
#
# to
#
# ['she', 'wants', 'talk', 'me']
#
# 4
#
# Or better still can you catch her and let ask her if she can sell  &lt;#&gt;  for me.
#
# or
#
# can
#
# her
#
# her
#
# she
#
# for
#
# ['better', 'still', 'you', 'catch', 'and', 'let', 'ask', 'if', 'can', 'sell', 'lt', 'gt', 'me']
#
# 13
#
# Don't make life too stressfull.. Always find time to Laugh.. It may not add years to your Life! But surely adds more life to ur years!! Gud ni8..swt dreams..
#
# don
#
# too
#
# to
#
# it
#
# not
#
# to
#
# but
#
# more
#
# to
#
# ['t', 'make', 'life', 'stressfull', 'always', 'find', 'time', 'laugh', 'may', 'add', 'years', 'your', 'life', 'surely', 'adds', 'life', 'ur', 'years', 'gud', 'ni8', 'swt', 'dreams']
#
# 22
#
# Remember to ask alex about his pizza
#
# to
#
# about
#
# ['remember', 'ask', 'alex', 'his', 'pizza']
#
# 5
#
# Not from this campus. Are you in the library?
#
# not
#
# this
#
# are
#
# in
#
# ['from', 'campus', 'you', 'the', 'library']
#
# 5
#
# Really dun bluff me leh... U sleep early too. Nite...
#
# me
#
# u
#
# too
#
# ['really', 'dun', 'bluff', 'leh', 'sleep', 'early', 'nite']
#
# 7
#
# Hottest pics straight to your phone!! See me getting Wet and Wanting, just for you xx Text PICS to 89555 now! txt costs 150p textoperator g696ga 18 XxX
#
# to
#
# me
#
# and
#
# just
#
# you
#
# to
#
# now
#
# ['hottest', 'pics', 'straight', 'your', 'phone', 'see', 'getting', 'wet', 'wanting', 'for', 'xx', 'text', 'pics', '89555', 'txt', 'costs', '150p', 'textoperator', 'g696ga', '18', 'xxx']
#
# 21
#
# Its on in engalnd! But telly has decided it won't let me watch it and mia and elliot were kissing! Damn it!
#
# its
#
# in
#
# but
#
# has
#
# it
#
# t
#
# me
#
# it
#
# and
#
# were
#
# it
#
# ['on', 'engalnd', 'telly', 'decided', 'won', 'let', 'watch', 'mia', 'and', 'elliot', 'kissing', 'damn']
#
# 12
#
# Nice. Wait...should you be texting right now? I'm not gonna pay your ticket, ya know!
#
# should
#
# be
#
# now
#
# not
#
# your
#
# ['nice', 'wait', 'you', 'texting', 'right', 'i', 'm', 'gonna', 'pay', 'ticket', 'ya', 'know']
#
# 12
#
# Alright we'll bring it to you, see you in like  &lt;#&gt;  mins
#
# we
#
# it
#
# you
#
# you
#
# ['alright', 'll', 'bring', 'to', 'see', 'in', 'like', 'lt', 'gt', 'mins']
#
# 10
#
# I think Iâ€˜m waiting for the same bus! Inform me when you get there, if you ever get there.
#
# i
#
# for
#
# same
#
# me
#
# you
#
# there
#
# you
#
# there
#
# ['think', 'iâ', 'm', 'waiting', 'the', 'bus', 'inform', 'when', 'get', 'if', 'ever', 'get']
#
# 12
#
# Thats cool. Where should i cum? On you or in you? :)
#
# where
#
# i
#
# on
#
# or
#
# you
#
# ['thats', 'cool', 'should', 'cum', 'in', 'you']
#
# 6
#
# Bbq this sat at mine from 6ish. Ur welcome 2 come
#
# this
#
# at
#
# from
#
# ur
#
# ['bbq', 'sat', 'mine', '6ish', 'welcome', '2', 'come']
#
# 7
#
# Good afternoon, my love ! Any job prospects ? Are you missing me ? What do you do ? Are you being lazy and bleak, hmmm ? Or happy and filled with my love ?
#
# my
#
# any
#
# are
#
# me
#
# do
#
# do
#
# you
#
# and
#
# or
#
# and
#
# with
#
# ['good', 'afternoon', 'love', 'job', 'prospects', 'missing', 'what', 'you', 'are', 'you', 'being', 'lazy', 'bleak', 'hmmm', 'happy', 'filled', 'my', 'love']
#
# 18
#
# You are being contacted by our Dating Service by someone you know! To find out who it is, call from your mobile or landline 09064017305 PoBox75LDNS7
#
# you
#
# being
#
# by
#
# by
#
# you
#
# to
#
# out
#
# it
#
# from
#
# or
#
# ['are', 'contacted', 'our', 'dating', 'service', 'someone', 'know', 'find', 'who', 'is', 'call', 'your', 'mobile', 'landline', '09064017305', 'pobox75ldns7']
#
# 16
#
# PRIVATE! Your 2004 Account Statement for 078498****7 shows 786 unredeemed Bonus Points. To claim call 08719180219 Identifier Code: 45239 Expires 06.05.05
#
# your
#
# for
#
# to
#
# ['private', '2004', 'account', 'statement', '078498', '7', 'shows', '786', 'unredeemed', 'bonus', 'points', 'claim', 'call', '08719180219', 'identifier', 'code', '45239', 'expires', '06', '05', '05']
#
# 21
#
# Do u noe wat time e place dat sells 4d closes?
#
# do
#
# ['u', 'noe', 'wat', 'time', 'e', 'place', 'dat', 'sells', '4d', 'closes']
#
# 10
#
# There are many company. Tell me the language.
#
# there
#
# me
#
# ['are', 'many', 'company', 'tell', 'the', 'language']
#
# 6
#
# Dear Voucher Holder, To claim this weeks offer, at your PC please go to http://www.wtlp.co.uk/text. Ts&Cs apply.
#
# to
#
# this
#
# at
#
# to
#
# ['dear', 'voucher', 'holder', 'claim', 'weeks', 'offer', 'your', 'pc', 'please', 'go', 'http', 'www', 'wtlp', 'co', 'uk', 'text', 'ts', 'cs', 'apply']
#
# 19
#
# Did you get any gift? This year i didnt get anything. So bad
#
# did
#
# any
#
# this
#
# i
#
# so
#
# ['you', 'get', 'gift', 'year', 'didnt', 'get', 'anything', 'bad']
#
# 8
#
# I am not sure about night menu. . . I know only about noon menu
#
# i
#
# not
#
# about
#
# i
#
# only
#
# ['am', 'sure', 'night', 'menu', 'know', 'about', 'noon', 'menu']
#
# 8
#
# Got it..mail panren paru..
#
# it
#
# ['got', 'mail', 'panren', 'paru']
#
# 4
#
# Doing my masters. When will you buy a bb cos i have for sale and how's bf
#
# doing
#
# when
#
# you
#
# a
#
# i
#
# for
#
# and
#
# s
#
# ['my', 'masters', 'will', 'buy', 'bb', 'cos', 'have', 'sale', 'how', 'bf']
#
# 10
#
# I shall book chez jules for half eight, if that's ok with you?
#
# i
#
# for
#
# if
#
# s
#
# with
#
# ['shall', 'book', 'chez', 'jules', 'half', 'eight', 'that', 'ok', 'you']
#
# 9
#
# So that takes away some money worries
#
# so
#
# some
#
# ['that', 'takes', 'away', 'money', 'worries']
#
# 5
#
# If you r @ home then come down within 5 min
#
# if
#
# then
#
# down
#
# ['you', 'r', 'home', 'come', 'within', '5', 'min']
#
# 7
#
# "CHA QUITEAMUZING THAT'SCOOL BABE,PROBPOP IN & CU SATTHEN HUNNY 4BREKKIE! LOVE JEN XXX. PSXTRA LRG PORTIONS 4 ME PLEASE "
#
# that
#
# in
#
# me
#
# ['cha', 'quiteamuzing', 'scool', 'babe', 'probpop', 'cu', 'satthen', 'hunny', '4brekkie', 'love', 'jen', 'xxx', 'psxtra', 'lrg', 'portions', '4', 'please']
#
# 17
#
# I just cooked a rather nice salmon a la you
#
# i
#
# a
#
# a
#
# you
#
# ['just', 'cooked', 'rather', 'nice', 'salmon', 'la']
#
# 6
#
# Gain the rights of a wife.dont demand it.i am trying as husband too.Lets see
#
# the
#
# of
#
# it
#
# am
#
# as
#
# too
#
# ['gain', 'rights', 'a', 'wife', 'dont', 'demand', 'i', 'trying', 'husband', 'lets', 'see']
#
# 11
#
# This message is brought to you by GMW Ltd. and is not connected to the
#
# this
#
# is
#
# to
#
# by
#
# and
#
# not
#
# to
#
# ['message', 'brought', 'you', 'gmw', 'ltd', 'is', 'connected', 'the']
#
# 8
#
# Where did u go? My phone is gonna die you have to stay in here
#
# where
#
# u
#
# my
#
# is
#
# you
#
# to
#
# in
#
# ['did', 'go', 'phone', 'gonna', 'die', 'have', 'stay', 'here']
#
# 8
#
# Hi dear we saw dear. We both are happy. Where you my battery is low
#
# we
#
# we
#
# are
#
# where
#
# my
#
# is
#
# ['hi', 'dear', 'saw', 'dear', 'both', 'happy', 'you', 'battery', 'low']
#
# 9
#
# That's fine, I'll bitch at you about it later then
#
# that
#
# i
#
# at
#
# about
#
# then
#
# ['s', 'fine', 'll', 'bitch', 'you', 'it', 'later']
#
# 7
#
# Prabha..i'm soryda..realy..frm heart i'm sory
#
# i
#
# i
#
# ['prabha', 'm', 'soryda', 'realy', 'frm', 'heart', 'm', 'sory']
#
# 8
#
# Not course. Only maths one day one chapter with in one month we can finish.
#
# not
#
# only
#
# with
#
# we
#
# ['course', 'maths', 'one', 'day', 'one', 'chapter', 'in', 'one', 'month', 'can', 'finish']
#
# 11
#
# Hmm... Dunno leh, mayb a bag 4 goigng out dat is not too small. Or jus anything except perfume, smth dat i can keep.
#
# a
#
# out
#
# is
#
# too
#
# or
#
# i
#
# ['hmm', 'dunno', 'leh', 'mayb', 'bag', '4', 'goigng', 'dat', 'not', 'small', 'jus', 'anything', 'except', 'perfume', 'smth', 'dat', 'can', 'keep']
#
# 18
#
# Hey u still at the gym?
#
# u
#
# at
#
# ['hey', 'still', 'the', 'gym']
#
# 4
#
# I'm really sorry i won't b able 2 do this friday.hope u can find an alternative.hope yr term's going ok:-)
#
# i
#
# i
#
# t
#
# do
#
# u
#
# an
#
# s
#
# ['m', 'really', 'sorry', 'won', 'b', 'able', '2', 'this', 'friday', 'hope', 'can', 'find', 'alternative', 'hope', 'yr', 'term', 'going', 'ok']
#
# 18
#
# How come she can get it? Should b quite diff to guess rite...
#
# how
#
# she
#
# it
#
# to
#
# ['come', 'can', 'get', 'should', 'b', 'quite', 'diff', 'guess', 'rite']
#
# 9
#
# Pls help me tell sura that i'm expecting a battery from hont. And that if should pls send me a message about how to download movies. Thanks
#
# me
#
# that
#
# a
#
# from
#
# and
#
# if
#
# me
#
# about
#
# to
#
# ['pls', 'help', 'tell', 'sura', 'i', 'm', 'expecting', 'battery', 'hont', 'that', 'should', 'pls', 'send', 'a', 'message', 'how', 'download', 'movies', 'thanks']
#
# 19
#
# I have had two more letters from . I will copy them for you cos one has a message for you. Speak soon
#
# i
#
# had
#
# more
#
# from
#
# will
#
# them
#
# you
#
# has
#
# for
#
# ['have', 'two', 'letters', 'i', 'copy', 'cos', 'one', 'a', 'message', 'for', 'you', 'speak', 'soon']
#
# 13
#
# I have 2 sleeping bags, 1 blanket and paper and  phone details. Anything else?
#
# i
#
# and
#
# and
#
# ['have', '2', 'sleeping', 'bags', '1', 'blanket', 'paper', 'phone', 'details', 'anything', 'else']
#
# 11
#
# Geeeee ... Your internet is really bad today, eh ?
#
# your
#
# is
#
# ['geeeee', 'internet', 'really', 'bad', 'today', 'eh']
#
# 6
#
# okmail: Dear Dave this is your final notice to collect your 4* Tenerife Holiday or #5000 CASH award! Call 09061743806 from landline. TCs SAE Box326 CW25WX 150ppm
#
# this
#
# your
#
# to
#
# your
#
# or
#
# from
#
# ['okmail', 'dear', 'dave', 'is', 'final', 'notice', 'collect', '4', 'tenerife', 'holiday', '5000', 'cash', 'award', 'call', '09061743806', 'landline', 'tcs', 'sae', 'box326', 'cw25wx', '150ppm']
#
# 21
#
# Was it something u ate?
#
# was
#
# u
#
# ['it', 'something', 'ate']
#
# 3
#
# You will go to walmart. I.ll stay.
#
# you
#
# to
#
# i
#
# ['will', 'go', 'walmart', 'll', 'stay']
#
# 5
#
# FreeMsg:Feelin kinda lnly hope u like 2 keep me company! Jst got a cam moby wanna c my pic?Txt or reply DATE to 82242 Msg150p 2rcv Hlp 08712317606 stop to 82242
#
# u
#
# me
#
# a
#
# my
#
# or
#
# to
#
# to
#
# ['freemsg', 'feelin', 'kinda', 'lnly', 'hope', 'like', '2', 'keep', 'company', 'jst', 'got', 'cam', 'moby', 'wanna', 'c', 'pic', 'txt', 'reply', 'date', '82242', 'msg150p', '2rcv', 'hlp', '08712317606', 'stop', '82242']
#
# 26
#
# Sorry, I'll call later
#
# i
#
# ['sorry', 'll', 'call', 'later']
#
# 4
#
# I like you peoples very much:) but am very shy pa.
#
# i
#
# you
#
# very
#
# but
#
# very
#
# ['like', 'peoples', 'much', 'am', 'shy', 'pa']
#
# 6
#
# Sounds gd... Haha... Can... Wah, u yan jiu so fast liao...
#
# can
#
# u
#
# so
#
# ['sounds', 'gd', 'haha', 'wah', 'yan', 'jiu', 'fast', 'liao']
#
# 8
#
# Dun need to use dial up juz open da browser n surf...
#
# to
#
# up
#
# da
#
# ['dun', 'need', 'use', 'dial', 'juz', 'open', 'browser', 'n', 'surf']
#
# 9
#
# Can you plz tell me the ans. BSLVYL sent via fullonsms.com
#
# can
#
# me
#
# ['you', 'plz', 'tell', 'the', 'ans', 'bslvyl', 'sent', 'via', 'fullonsms', 'com']
#
# 10
#
# Are you willing to go for apps class.
#
# are
#
# to
#
# for
#
# ['you', 'willing', 'go', 'apps', 'class']
#
# 5
#
# Sounds like a plan! Cardiff is still here and still cold! I'm sitting on the radiator!
#
# a
#
# is
#
# here
#
# i
#
# on
#
# ['sounds', 'like', 'plan', 'cardiff', 'still', 'and', 'still', 'cold', 'm', 'sitting', 'the', 'radiator']
#
# 12
#
# Or maybe my fat fingers just press all these buttons and it doesn't know what to do.
#
# or
#
# my
#
# just
#
# all
#
# and
#
# t
#
# what
#
# do
#
# ['maybe', 'fat', 'fingers', 'press', 'these', 'buttons', 'it', 'doesn', 'know', 'to']
#
# 10
#
# Hello, my boytoy! I made it home and my constant thought is of you, my love. I hope your having a nice visit but I can't wait till you come home to me ...*kiss*
#
# my
#
# i
#
# it
#
# and
#
# is
#
# you
#
# i
#
# your
#
# a
#
# but
#
# can
#
# you
#
# to
#
# ['hello', 'boytoy', 'made', 'home', 'my', 'constant', 'thought', 'of', 'my', 'love', 'hope', 'having', 'nice', 'visit', 'i', 't', 'wait', 'till', 'come', 'home', 'me', 'kiss']
#
# 22
#
# I'm at work. Please call
#
# i
#
# at
#
# ['m', 'work', 'please', 'call']
#
# 4
#
# So dont use hook up any how
#
# so
#
# up
#
# how
#
# ['dont', 'use', 'hook', 'any']
#
# 4
#
# Ugh. Gotta drive back to sd from la. My butt is sore.
#
# to
#
# from
#
# my
#
# is
#
# ['ugh', 'gotta', 'drive', 'back', 'sd', 'la', 'butt', 'sore']
#
# 8
#
# Its sarcasm.. .nt scarcasim
#
# its
#
# ['sarcasm', 'nt', 'scarcasim']
#
# 3
#
# Yes da. Any plm at ur office
#
# da
#
# at
#
# ['yes', 'any', 'plm', 'ur', 'office']
#
# 5
#
# Nationwide auto centre (or something like that) on Newport road. I liked them there
#
# or
#
# that
#
# i
#
# them
#
# ['nationwide', 'auto', 'centre', 'something', 'like', 'on', 'newport', 'road', 'liked', 'there']
#
# 10
#
# Text PASS to 69669 to collect your polyphonic ringtones. Normal gprs charges apply only. Enjoy your tones
#
# to
#
# to
#
# your
#
# only
#
# your
#
# ['text', 'pass', '69669', 'collect', 'polyphonic', 'ringtones', 'normal', 'gprs', 'charges', 'apply', 'enjoy', 'tones']
#
# 12
#
# Wow ... I love you sooo much, you know ? I can barely stand it ! I wonder how your day goes and if you are well, my love ... I think of you and miss you
#
# i
#
# you
#
# you
#
# i
#
# it
#
# how
#
# and
#
# you
#
# my
#
# i
#
# of
#
# and
#
# you
#
# ['wow', 'love', 'sooo', 'much', 'know', 'can', 'barely', 'stand', 'wonder', 'your', 'day', 'goes', 'if', 'are', 'well', 'love', 'i', 'think', 'miss', 'you']
#
# 20
#
# URGENT! Your Mobile No was awarded a Â£2,000 Bonus Caller Prize on 1/08/03! This is our 2nd attempt to contact YOU! Call 0871-4719-523 BOX95QU BT National Rate
#
# your
#
# no
#
# a
#
# on
#
# this
#
# our
#
# to
#
# you
#
# ['urgent', 'mobile', 'was', 'awarded', 'â', '2', '000', 'bonus', 'caller', 'prize', '1', '08', '03', 'is', '2nd', 'attempt', 'contact', 'call', '0871', '4719', '523', 'box95qu', 'bt', 'national', 'rate']
#
# 25
#
# (And my man carlos is definitely coming by mu tonight, no excuses)
#
# and
#
# is
#
# by
#
# no
#
# ['my', 'man', 'carlos', 'definitely', 'coming', 'mu', 'tonight', 'excuses']
#
# 8
#
# Hi, my love! How goes that day? Fuck, this morning I woke and dropped my cell on the way down the stairs but it seems alright ... *phews* I miss you !
#
# my
#
# how
#
# that
#
# this
#
# i
#
# and
#
# my
#
# on
#
# down
#
# but
#
# i
#
# you
#
# ['hi', 'love', 'goes', 'day', 'fuck', 'morning', 'woke', 'dropped', 'cell', 'the', 'way', 'the', 'stairs', 'it', 'seems', 'alright', 'phews', 'miss']
#
# 18
#
# oh ya... Got hip hop open. Haha i was thinking can go for jazz then zoom to cine... Actually tonight i'm free leh... And there's a kb lesson tonight
#
# i
#
# can
#
# for
#
# then
#
# to
#
# i
#
# and
#
# s
#
# ['oh', 'ya', 'got', 'hip', 'hop', 'open', 'haha', 'was', 'thinking', 'go', 'jazz', 'zoom', 'cine', 'actually', 'tonight', 'm', 'free', 'leh', 'there', 'a', 'kb', 'lesson', 'tonight']
#
# 23
#
# FREE entry into our Â£250 weekly comp just send the word ENTER to 84128 NOW. 18 T&C www.textcomp.com cust care 08712405020.
#
# into
#
# just
#
# the
#
# to
#
# now
#
# t
#
# ['free', 'entry', 'our', 'â', '250', 'weekly', 'comp', 'send', 'word', 'enter', '84128', '18', 'c', 'www', 'textcomp', 'com', 'cust', 'care', '08712405020']
#
# 19
#
# Surly ill give it to you:-) while coming to review.
#
# it
#
# you
#
# to
#
# ['surly', 'ill', 'give', 'while', 'coming', 'to', 'review']
#
# 7
#
# Yes obviously, but you are the eggs-pert and the potato headâ€¦ Speak soon!
#
# but
#
# are
#
# and
#
# ['yes', 'obviously', 'you', 'the', 'eggs', 'pert', 'the', 'potato', 'headâ', '¦', 'speak', 'soon']
#
# 12
#
# Then anything special?
#
# then
#
# ['anything', 'special']
#
# 2
#
# She left it very vague. She just said she would inform the person in accounting about the delayed rent and that i should discuss with the housing agency about my renting another place. But checking online now and all places around usc are  &lt;#&gt;  and up
#
# she
#
# it
#
# she
#
# she
#
# the
#
# in
#
# about
#
# and
#
# i
#
# with
#
# about
#
# but
#
# now
#
# all
#
# are
#
# and
#
# ['left', 'very', 'vague', 'just', 'said', 'would', 'inform', 'person', 'accounting', 'the', 'delayed', 'rent', 'that', 'should', 'discuss', 'the', 'housing', 'agency', 'my', 'renting', 'another', 'place', 'checking', 'online', 'places', 'around', 'usc', 'lt', 'gt', 'and', 'up']
#
# 31
#
# Thanks for your ringtone order, reference number X49. Your mobile will be charged 4.50. Should your tone not arrive please call customer services 09065989182. From: [colour=red]text[/colour]TXTstar
#
# for
#
# your
#
# will
#
# should
#
# not
#
# from
#
# ['thanks', 'ringtone', 'order', 'reference', 'number', 'x49', 'your', 'mobile', 'be', 'charged', '4', '50', 'your', 'tone', 'arrive', 'please', 'call', 'customer', 'services', '09065989182', 'colour=red', 'text', 'colour', 'txtstar']
#
# 24
#
# Do you work all this week ?
#
# do
#
# all
#
# ['you', 'work', 'this', 'week']
#
# 4
#
# Yeah, probably but not sure. Ilol let u know, but personally I wuldnt bother, then again if ur goin to then I mite as well!!
#
# but
#
# u
#
# but
#
# i
#
# then
#
# if
#
# to
#
# i
#
# as
#
# ['yeah', 'probably', 'not', 'sure', 'ilol', 'let', 'know', 'personally', 'wuldnt', 'bother', 'again', 'ur', 'goin', 'then', 'mite', 'well']
#
# 16
#
# Please leave this topic..sorry for telling that..
#
# this
#
# for
#
# that
#
# ['please', 'leave', 'topic', 'sorry', 'telling']
#
# 5
#
# I'm at home. Please call
#
# i
#
# at
#
# ['m', 'home', 'please', 'call']
#
# 4
#
# Urgent! Please call 0906346330. Your ABTA complimentary 4* Spanish Holiday or Â£10,000 cash await collection SAE T&Cs BOX 47 PO19 2EZ 150ppm 18+
#
# your
#
# or
#
# t
#
# ['urgent', 'please', 'call', '0906346330', 'abta', 'complimentary', '4', 'spanish', 'holiday', 'â', '10', '000', 'cash', 'await', 'collection', 'sae', 'cs', 'box', '47', 'po19', '2ez', '150ppm', '18+']
#
# 23
#
# Dont flatter yourself... Tell that man of mine two pints of carlin in ten minutes please....
#
# yourself
#
# that
#
# of
#
# of
#
# in
#
# ['dont', 'flatter', 'tell', 'man', 'mine', 'two', 'pints', 'carlin', 'ten', 'minutes', 'please']
#
# 11
#
# Babe !!!! I LOVE YOU !!!! *covers your face in kisses*
#
# i
#
# you
#
# your
#
# in
#
# ['babe', 'love', 'covers', 'face', 'kisses']
#
# 5
#
# Good evening! this is roger. How are you?
#
# this
#
# how
#
# you
#
# ['good', 'evening', 'is', 'roger', 'are']
#
# 5
#
# HMV BONUS SPECIAL 500 pounds of genuine HMV vouchers to be won. Just answer 4 easy questions. Play Now! Send HMV to 86688 More info:www.100percent-real.com
#
# of
#
# to
#
# just
#
# now
#
# to
#
# more
#
# ['hmv', 'bonus', 'special', '500', 'pounds', 'genuine', 'hmv', 'vouchers', 'be', 'won', 'answer', '4', 'easy', 'questions', 'play', 'send', 'hmv', '86688', 'info', 'www', '100percent', 'real', 'com']
#
# 23
#
# I love u 2 my little pocy bell I am sorry but I love u
#
# i
#
# u
#
# my
#
# i
#
# but
#
# u
#
# ['love', '2', 'little', 'pocy', 'bell', 'am', 'sorry', 'i', 'love']
#
# 9
#
# Yes watching footie but worried we're going to blow it - Phil Neville?
#
# but
#
# we
#
# to
#
# it
#
# ['yes', 'watching', 'footie', 'worried', 're', 'going', 'blow', 'phil', 'neville']
#
# 9
#
# So that means you still think of teju
#
# so
#
# you
#
# of
#
# ['that', 'means', 'still', 'think', 'teju']
#
# 5
#
# So i asked how's anthony. Dad. And your bf
#
# so
#
# how
#
# and
#
# ['i', 'asked', 's', 'anthony', 'dad', 'your', 'bf']
#
# 7
#
# Only just got this message, not ignoring you. Yes, i was. Shopping that is
#
# only
#
# this
#
# not
#
# you
#
# i
#
# that
#
# ['just', 'got', 'message', 'ignoring', 'yes', 'was', 'shopping', 'is']
#
# 8
#
# Aight ill get on fb in a couple minutes
#
# on
#
# in
#
# ['aight', 'ill', 'get', 'fb', 'a', 'couple', 'minutes']
#
# 7
#
# That's very rude, you on campus?
#
# that
#
# very
#
# you
#
# ['s', 'rude', 'on', 'campus']
#
# 4
#
# I'm still pretty weak today .. Bad day ?
#
# i
#
# ['m', 'still', 'pretty', 'weak', 'today', 'bad', 'day']
#
# 7
#
# Jus finish bathing...
#
# ['jus', 'finish', 'bathing']
#
# 3
#
# Congratulations U can claim 2 VIP row A Tickets 2 C Blu in concert in November or Blu gift guaranteed Call 09061104276 to claim TS&Cs www.smsco.net costÂ£3.75max
#
# u
#
# a
#
# in
#
# in
#
# or
#
# to
#
# ['congratulations', 'can', 'claim', '2', 'vip', 'row', 'tickets', '2', 'c', 'blu', 'concert', 'november', 'blu', 'gift', 'guaranteed', 'call', '09061104276', 'claim', 'ts', 'cs', 'www', 'smsco', 'net', 'costâ', '3', '75max']
#
# 26
#
# JADE ITS PAUL. Y DIDN'T U TXT ME? DO U REMEMBER ME FROM BARMED? I WANT 2 TALK 2 U! TXT ME
#
# its
#
# t
#
# me
#
# u
#
# me
#
# i
#
# u
#
# me
#
# ['jade', 'paul', 'y', 'didn', 'txt', 'do', 'remember', 'from', 'barmed', 'want', '2', 'talk', '2', 'u', 'txt']
#
# 15
#
# Wait, do you know if wesleys in town? I bet she does hella drugs!
#
# do
#
# if
#
# in
#
# i
#
# she
#
# ['wait', 'you', 'know', 'wesleys', 'town', 'bet', 'does', 'hella', 'drugs']
#
# 9
#
# Shall I bring us a bottle of wine to keep us amused? Only joking! Iâ€˜ll bring one anyway
#
# i
#
# a
#
# of
#
# to
#
# only
#
# ['shall', 'bring', 'us', 'bottle', 'wine', 'keep', 'us', 'amused', 'joking', 'iâ', 'll', 'bring', 'one', 'anyway']
#
# 14
#
# Oh that was a forwarded message. I thought you send that to me
#
# that
#
# a
#
# i
#
# you
#
# that
#
# me
#
# ['oh', 'was', 'forwarded', 'message', 'thought', 'send', 'to']
#
# 7
#
# Watching cartoon, listening music &amp; at eve had to go temple &amp; church.. What about u?
#
# at
#
# had
#
# what
#
# u
#
# ['watching', 'cartoon', 'listening', 'music', 'amp', 'eve', 'to', 'go', 'temple', 'amp', 'church', 'about']
#
# 12
#
# How much would it cost to hire a hitman
#
# how
#
# it
#
# to
#
# a
#
# ['much', 'would', 'cost', 'hire', 'hitman']
#
# 5
#
# Its sunny in california. The weather's just cool
#
# its
#
# in
#
# the
#
# s
#
# ['sunny', 'california', 'weather', 'just', 'cool']
#
# 5
#
# S da..al r above  &lt;#&gt;
#
# s
#
# above
#
# ['da', 'al', 'r', 'lt', 'gt']
#
# 5
#
# Jus finish blowing my hair. U finish dinner already?
#
# my
#
# u
#
# ['jus', 'finish', 'blowing', 'hair', 'finish', 'dinner', 'already']
#
# 7
#
# Correct. So how was work today
#
# so
#
# was
#
# ['correct', 'how', 'work', 'today']
#
# 4
#
# Da is good good player.why he is unsold.
#
# da
#
# why
#
# is
#
# ['good', 'good', 'player', 'he', 'is', 'unsold']
#
# 6
#
# Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile when sum1 Hurts U Smile becoz SOMEONE still Loves to see u Smiling!!
#
# in
#
# in
#
# when
#
# when
#
# u
#
# to
#
# u
#
# ['smile', 'pleasure', 'smile', 'pain', 'smile', 'trouble', 'pours', 'like', 'rain', 'smile', 'sum1', 'hurts', 'smile', 'becoz', 'someone', 'still', 'loves', 'see', 'smiling']
#
# 19
#
# Ard 530 like dat lor. We juz meet in mrt station then Ã¼ dun haf to come out.
#
# we
#
# in
#
# then
#
# to
#
# out
#
# ['ard', '530', 'like', 'dat', 'lor', 'juz', 'meet', 'mrt', 'station', 'ã¼', 'dun', 'haf', 'come']
#
# 13
#
# Can you use foreign stamps for whatever you send them off for?
#
# can
#
# for
#
# you
#
# them
#
# for
#
# ['use', 'foreign', 'stamps', 'whatever', 'you', 'send', 'off']
#
# 7
#
# I to am looking forward to all the sex cuddling.. Only two more sleeps
#
# i
#
# am
#
# to
#
# the
#
# only
#
# more
#
# ['looking', 'forward', 'to', 'all', 'sex', 'cuddling', 'two', 'sleeps']
#
# 8
#
# Probably money worries. Things are coming due and i have several outstanding invoices for work i did two and three months ago.
#
# are
#
# and
#
# have
#
# for
#
# i
#
# and
#
# ['probably', 'money', 'worries', 'things', 'coming', 'due', 'several', 'outstanding', 'invoices', 'work', 'i', 'did', 'two', 'three', 'months', 'ago']
#
# 16
#
#  what number do u live at? Is it 11?
#
# what
#
# do
#
# at
#
# it
#
# ['number', 'u', 'live', 'is', '11']
#
# 5
#
# Yes we were outside for like 2 hours. And I called my whole family to wake them up cause it started at 1 am
#
# we
#
# for
#
# and
#
# my
#
# to
#
# them
#
# it
#
# at
#
# am
#
# ['yes', 'were', 'outside', 'like', '2', 'hours', 'i', 'called', 'whole', 'family', 'wake', 'up', 'cause', 'started', '1']
#
# 15
#
# Keep yourself safe for me because I need you and I miss you already and I envy everyone that see's you in real life
#
# yourself
#
# for
#
# because
#
# you
#
# i
#
# you
#
# and
#
# that
#
# s
#
# in
#
# ['keep', 'safe', 'me', 'need', 'i', 'miss', 'already', 'and', 'i', 'envy', 'everyone', 'see', 'you', 'real', 'life']
#
# 15
#
# Mm i am on the way to railway
#
# i
#
# on
#
# to
#
# ['mm', 'am', 'the', 'way', 'railway']
#
# 5
#
# Now that you have started dont stop. Just pray for more good ideas and anything i see that can help you guys i.ll forward you a link.
#
# now
#
# you
#
# just
#
# for
#
# and
#
# i
#
# that
#
# you
#
# i
#
# you
#
# ['have', 'started', 'dont', 'stop', 'pray', 'more', 'good', 'ideas', 'anything', 'see', 'that', 'can', 'help', 'guys', 'll', 'forward', 'a', 'link']
#
# 18
#
# No need to buy lunch for me.. I eat maggi mee..
#
# no
#
# to
#
# for
#
# i
#
# ['need', 'buy', 'lunch', 'me', 'eat', 'maggi', 'mee']
#
# 7
#
# Sure but since my parents will be working on Tuesday I don't really need a cover story
#
# but
#
# my
#
# will
#
# on
#
# i
#
# t
#
# a
#
# ['sure', 'since', 'parents', 'be', 'working', 'tuesday', 'don', 'really', 'need', 'cover', 'story']
#
# 11
#
# Sorry, I'll call later
#
# i
#
# ['sorry', 'll', 'call', 'later']
#
# 4
#
# Dunno dat's wat he told me. Ok lor...
#
# s
#
# he
#
# me
#
# ['dunno', 'dat', 'wat', 'told', 'ok', 'lor']
#
# 6
#
# 5 Free Top Polyphonic Tones call 087018728737, National Rate. Get a toppoly tune sent every week, just text SUBPOLY to 81618, Â£3 per pole. UnSub 08718727870.
#
# a
#
# just
#
# to
#
# ['5', 'free', 'top', 'polyphonic', 'tones', 'call', '087018728737', 'national', 'rate', 'get', 'toppoly', 'tune', 'sent', 'every', 'week', 'text', 'subpoly', '81618', 'â', '3', 'per', 'pole', 'unsub', '08718727870']
#
# 24
#
# Then Ã¼ ask dad to pick Ã¼ up lar... Ãœ wan 2 stay until 6 meh...
#
# then
#
# to
#
# up
#
# until
#
# ['ã¼', 'ask', 'dad', 'pick', 'ã¼', 'lar', 'ãœ', 'wan', '2', 'stay', '6', 'meh']
#
# 12
#
# I'm good. Have you registered to vote?
#
# i
#
# have
#
# to
#
# ['m', 'good', 'you', 'registered', 'vote']
#
# 5
#
# Your bill at 3 is Â£33.65 so thats not bad!
#
# your
#
# at
#
# is
#
# so
#
# not
#
# ['bill', '3', 'â', '33', '65', 'thats', 'bad']
#
# 7
#
# It will stop on itself. I however suggest she stays with someone that will be able to give ors for every stool.
#
# it
#
# on
#
# i
#
# she
#
# with
#
# that
#
# be
#
# to
#
# for
#
# ['will', 'stop', 'itself', 'however', 'suggest', 'stays', 'someone', 'will', 'able', 'give', 'ors', 'every', 'stool']
#
# 13
#
# Babe ! What are you doing ? Where are you ? Who are you talking to ? Do you think of me ? Are you being a good boy? Are you missing me? Do you love me ?
#
# what
#
# you
#
# where
#
# you
#
# are
#
# to
#
# you
#
# of
#
# are
#
# being
#
# are
#
# me
#
# you
#
# me
#
# ['babe', 'doing', 'who', 'talking', 'do', 'think', 'are', 'you', 'a', 'good', 'boy', 'are', 'you', 'missing', 'do', 'you', 'love', 'me']
#
# 18
#
# Yo do you know anyone  &lt;#&gt;  or otherwise able to buy liquor? Our guy flaked and right now if we don't get a hold of somebody its just 4 loko all night
#
# do
#
# or
#
# to
#
# our
#
# and
#
# now
#
# we
#
# t
#
# a
#
# of
#
# its
#
# all
#
# ['yo', 'you', 'know', 'anyone', 'lt', 'gt', 'otherwise', 'able', 'buy', 'liquor', 'guy', 'flaked', 'right', 'if', 'don', 'get', 'hold', 'somebody', 'just', '4', 'loko', 'night']
#
# 22
#
# WIN URGENT! Your mobile number has been awarded with a Â£2000 prize GUARANTEED call 09061790121 from land line. claim 3030 valid 12hrs only 150ppm
#
# your
#
# has
#
# with
#
# from
#
# only
#
# ['win', 'urgent', 'mobile', 'number', 'been', 'awarded', 'a', 'â', '2000', 'prize', 'guaranteed', 'call', '09061790121', 'land', 'line', 'claim', '3030', 'valid', '12hrs', '150ppm']
#
# 20
#
# Dude just saw a parked car with its sunroof popped up. Sux
#
# just
#
# a
#
# with
#
# up
#
# ['dude', 'saw', 'parked', 'car', 'its', 'sunroof', 'popped', 'sux']
#
# 8
#
# Ok
#
# ['ok']
#
# 1
#
# Aight will do, thanks again for comin out
#
# will
#
# again
#
# out
#
# ['aight', 'do', 'thanks', 'for', 'comin']
#
# 5
#
# Mm i had my food da from out
#
# i
#
# my
#
# da
#
# out
#
# ['mm', 'had', 'food', 'from']
#
# 4
#
# I am in tirupur da, once you started from office call me.
#
# i
#
# in
#
# da
#
# you
#
# from
#
# me
#
# ['am', 'tirupur', 'once', 'started', 'office', 'call']
#
# 6
#
# Hello boytoy ! Geeee ... I'm missing you today. I like to send you a tm and remind you I'm thinking of you ... And you are loved ... *loving kiss*
#
# i
#
# you
#
# i
#
# to
#
# you
#
# and
#
# you
#
# of
#
# and
#
# are
#
# ['hello', 'boytoy', 'geeee', 'm', 'missing', 'today', 'like', 'send', 'a', 'tm', 'remind', 'i', 'm', 'thinking', 'you', 'you', 'loved', 'loving', 'kiss']
#
# 19
#
# Awesome, I remember the last time we got somebody high for the first time with diesel :V
#
# i
#
# the
#
# we
#
# for
#
# with
#
# ['awesome', 'remember', 'last', 'time', 'got', 'somebody', 'high', 'the', 'first', 'time', 'diesel', 'v']
#
# 12
#
# HI DARLIN ITS KATE ARE U UP FOR DOIN SOMETHIN TONIGHT? IM GOING TO A PUB CALLED THE SWAN OR SOMETHING WITH MY PARENTS FOR ONE DRINK SO PHONE ME IF U CAN
#
# its
#
# are
#
# up
#
# to
#
# the
#
# or
#
# with
#
# for
#
# so
#
# me
#
# u
#
# ['hi', 'darlin', 'kate', 'doin', 'somethin', 'tonight', 'im', 'going', 'a', 'pub', 'called', 'swan', 'something', 'my', 'parents', 'for', 'one', 'drink', 'phone', 'if', 'u', 'can']
#
# 22
#
# Pls speak with me. I wont ask anything other then you friendship.
#
# with
#
# i
#
# other
#
# you
#
# ['pls', 'speak', 'me', 'wont', 'ask', 'anything', 'then', 'friendship']
#
# 8
#
# I keep seeing weird shit and bein all "woah" then realising it's actually reasonable and I'm all "oh"
#
# i
#
# and
#
# all
#
# then
#
# it
#
# and
#
# all
#
# ['keep', 'seeing', 'weird', 'shit', 'bein', 'woah', 'realising', 's', 'actually', 'reasonable', 'i', 'm', 'oh']
#
# 13
#
# What not under standing.
#
# what
#
# under
#
# ['not', 'standing']
#
# 2
#
# He remains a bro amongst bros
#
# he
#
# a
#
# ['remains', 'bro', 'amongst', 'bros']
#
# 4
#
# Yup ok thanx...
#
# ['yup', 'ok', 'thanx']
#
# 3
#
# I am going to film 2day da. At 6pm. Sorry da.
#
# i
#
# to
#
# da
#
# da
#
# ['am', 'going', 'film', '2day', 'at', '6pm', 'sorry']
#
# 7
#
# We currently have a message awaiting your collection. To collect your message just call 08718723815.
#
# we
#
# have
#
# your
#
# to
#
# your
#
# just
#
# ['currently', 'a', 'message', 'awaiting', 'collection', 'collect', 'message', 'call', '08718723815']
#
# 9
#
# No calls..messages..missed calls
#
# no
#
# ['calls', 'messages', 'missed', 'calls']
#
# 4
#
# And he's apparently bffs with carly quick now
#
# and
#
# s
#
# with
#
# now
#
# ['he', 'apparently', 'bffs', 'carly', 'quick']
#
# 5
#
# I am in your office na.
#
# i
#
# in
#
# ['am', 'your', 'office', 'na']
#
# 4
#
# Alright omw, gotta change my order to a half8th
#
# my
#
# to
#
# ['alright', 'omw', 'gotta', 'change', 'order', 'a', 'half8th']
#
# 7
#
# The Xmas story is peace.. The Xmas msg is love.. The Xmas miracle is jesus.. Hav a blessed month ahead &amp; wish U Merry Xmas...
#
# the
#
# is
#
# the
#
# is
#
# the
#
# is
#
# a
#
# u
#
# ['xmas', 'story', 'peace', 'xmas', 'msg', 'love', 'xmas', 'miracle', 'jesus', 'hav', 'blessed', 'month', 'ahead', 'amp', 'wish', 'merry', 'xmas']
#
# 17
#
# A Â£400 XMAS REWARD IS WAITING FOR YOU! Our computer has randomly picked you from our loyal mobile customers to receive a Â£400 reward. Just call 09066380611
#
# a
#
# is
#
# for
#
# our
#
# has
#
# you
#
# our
#
# to
#
# a
#
# just
#
# ['â', '400', 'xmas', 'reward', 'waiting', 'computer', 'randomly', 'picked', 'you', 'from', 'loyal', 'mobile', 'customers', 'receive', 'â', '400', 'reward', 'call', '09066380611']
#
# 19
#
# +123 Congratulations - in this week's competition draw u have won the Â£1450 prize to claim just call 09050002311 b4280703. T&Cs/stop SMS 08718727868. Over 18 only 150ppm
#
# in
#
# s
#
# u
#
# the
#
# to
#
# just
#
# t
#
# over
#
# only
#
# ['+123', 'congratulations', 'this', 'week', 'competition', 'draw', 'have', 'won', 'â', '1450', 'prize', 'claim', 'call', '09050002311', 'b4280703', 'cs', 'stop', 'sms', '08718727868', '18', '150ppm']
#
# 21
#
# As per your request 'Maangalyam (Alaipayuthe)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune
#
# as
#
# your
#
# has
#
# as
#
# for
#
# to
#
# your
#
# ['per', 'request', 'maangalyam', 'alaipayuthe', 'been', 'set', 'callertune', 'all', 'callers', 'press', '9', 'copy', 'your', 'friends', 'callertune']
#
# 15
#
# Superb Thought- "Be grateful that u dont have everything u want. That means u still have an opportunity to be happier tomorrow than u are today.":-)
#
# be
#
# that
#
# have
#
# u
#
# that
#
# u
#
# have
#
# to
#
# than
#
# are
#
# ['superb', 'thought', 'grateful', 'dont', 'everything', 'want', 'means', 'u', 'still', 'an', 'opportunity', 'be', 'happier', 'tomorrow', 'u', 'today']
#
# 16
#
# Do you think i can move  &lt;#&gt;  in a week
#
# do
#
# i
#
# in
#
# ['you', 'think', 'can', 'move', 'lt', 'gt', 'a', 'week']
#
# 8
#
# Do you want a new Video phone? 600 anytime any network mins 400 Inclusive Video calls AND downloads 5 per week Free delTOMORROW call 08002888812 or reply NOW
#
# do
#
# a
#
# any
#
# and
#
# or
#
# now
#
# ['you', 'want', 'new', 'video', 'phone', '600', 'anytime', 'network', 'mins', '400', 'inclusive', 'video', 'calls', 'downloads', '5', 'per', 'week', 'free', 'deltomorrow', 'call', '08002888812', 'reply']
#
# 22
#
# You still coming tonight?
#
# you
#
# ['still', 'coming', 'tonight']
#
# 3
#
# Yes.. now only saw your message..
#
# now
#
# your
#
# ['yes', 'only', 'saw', 'message']
#
# 4
#
# Thanks. It was only from tescos but quite nice. All gone now. Speak soon
#
# it
#
# only
#
# but
#
# all
#
# now
#
# ['thanks', 'was', 'from', 'tescos', 'quite', 'nice', 'gone', 'speak', 'soon']
#
# 9
#
# It shall be fine. I have avalarr now. Will hollalater
#
# it
#
# be
#
# i
#
# now
#
# ['shall', 'fine', 'have', 'avalarr', 'will', 'hollalater']
#
# 6
#
# FreeMsg Today's the day if you are ready! I'm horny & live in your town. I love sex fun & games! Netcollex Ltd 08700621170150p per msg reply Stop to end
#
# s
#
# if
#
# are
#
# i
#
# in
#
# i
#
# to
#
# ['freemsg', 'today', 'the', 'day', 'you', 'ready', 'm', 'horny', 'live', 'your', 'town', 'love', 'sex', 'fun', 'games', 'netcollex', 'ltd', '08700621170150p', 'per', 'msg', 'reply', 'stop', 'end']
#
# 23
#
# Yeah, that's fine! It's Â£6 to get in, is that ok?
#
# that
#
# it
#
# to
#
# in
#
# that
#
# ['yeah', 's', 'fine', 's', 'â', '6', 'get', 'is', 'ok']
#
# 9
#
# When Ã¼ login dat time... Dad fetching Ã¼ home now?
#
# when
#
# now
#
# ['ã¼', 'login', 'dat', 'time', 'dad', 'fetching', 'ã¼', 'home']
#
# 8
#
# Hey mr  and I are going to the sea view and having a couple of gays I mean games! Give me a bell when ya finish
#
# and
#
# are
#
# to
#
# and
#
# a
#
# of
#
# i
#
# me
#
# when
#
# ['hey', 'mr', 'going', 'the', 'sea', 'view', 'having', 'couple', 'gays', 'i', 'mean', 'games', 'give', 'a', 'bell', 'ya', 'finish']
#
# 17
#
# SORRY IM STIL FUCKED AFTER LAST NITE WENT TOBED AT 430 GOT UP 4 WORK AT 630
#
# after
#
# at
#
# up
#
# at
#
# ['sorry', 'im', 'stil', 'fucked', 'last', 'nite', 'went', 'tobed', '430', 'got', '4', 'work', '630']
#
# 13
#
# Are you being good, baby? :)
#
# are
#
# being
#
# ['you', 'good', 'baby']
#
# 3
#
# I'm done oredi...
#
# i
#
# ['m', 'done', 'oredi']
#
# 3
#
# Wat time liao, where still got.
#
# where
#
# ['wat', 'time', 'liao', 'still', 'got']
#
# 5
#
# Hi its Kate how is your evening? I hope i can see you tomorrow for a bit but i have to bloody babyjontet! Txt back if u can. :) xxx
#
# its
#
# how
#
# your
#
# i
#
# i
#
# you
#
# for
#
# but
#
# have
#
# if
#
# can
#
# ['hi', 'kate', 'is', 'evening', 'hope', 'see', 'tomorrow', 'a', 'bit', 'i', 'to', 'bloody', 'babyjontet', 'txt', 'back', 'u', 'can', 'xxx']
#
# 18
#
# If you're still up, maybe leave the credit card so I can get gas when I get back like he told me to
#
# if
#
# up
#
# the
#
# so
#
# can
#
# when
#
# he
#
# me
#
# ['you', 're', 'still', 'maybe', 'leave', 'credit', 'card', 'i', 'get', 'gas', 'i', 'get', 'back', 'like', 'told', 'to']
#
# 16
#
# Ok lor...
#
# ['ok', 'lor']
#
# 2
#
# I WILL CAL YOU SIR. In meeting
#
# i
#
# you
#
# in
#
# ['will', 'cal', 'sir', 'meeting']
#
# 4
#
# 2p per min to call Germany 08448350055 from your BT line. Just 2p per min. Check PlanetTalkInstant.com for info & T's & C's. Text stop to opt out
#
# to
#
# from
#
# just
#
# for
#
# t
#
# s
#
# to
#
# out
#
# ['2p', 'per', 'min', 'call', 'germany', '08448350055', 'your', 'bt', 'line', '2p', 'per', 'min', 'check', 'planettalkinstant', 'com', 'info', 'c', 's', 'text', 'stop', 'opt']
#
# 21
#
# I wonder how you got online, my love ? Had you gone to the net cafe ? Did you get your phone recharged ? Were you on a friends net ? I think of you, boytoy
#
# i
#
# how
#
# my
#
# had
#
# to
#
# did
#
# your
#
# were
#
# on
#
# i
#
# of
#
# ['wonder', 'you', 'got', 'online', 'love', 'you', 'gone', 'the', 'net', 'cafe', 'you', 'get', 'phone', 'recharged', 'you', 'a', 'friends', 'net', 'think', 'you', 'boytoy']
#
# 21
#
# Sorry, I guess whenever I can get a hold of my connections, maybe an hour or two? I'll text you
#
# i
#
# i
#
# a
#
# of
#
# an
#
# or
#
# i
#
# you
#
# ['sorry', 'guess', 'whenever', 'can', 'get', 'hold', 'my', 'connections', 'maybe', 'hour', 'two', 'll', 'text']
#
# 13
#
# Yo we are watching a movie on netflix
#
# we
#
# a
#
# on
#
# ['yo', 'are', 'watching', 'movie', 'netflix']
#
# 5
#
# URGENT! Your Mobile No 07808726822 was awarded a Â£2,000 Bonus Caller Prize on 02/09/03! This is our 2nd attempt to contact YOU! Call 0871-872-9758 BOX95QU
#
# your
#
# no
#
# was
#
# a
#
# on
#
# this
#
# our
#
# to
#
# you
#
# ['urgent', 'mobile', '07808726822', 'awarded', 'â', '2', '000', 'bonus', 'caller', 'prize', '02', '09', '03', 'is', '2nd', 'attempt', 'contact', 'call', '0871', '872', '9758', 'box95qu']
#
# 22
#
# Tone Club: Your subs has now expired 2 re-sub reply MONOC 4 monos or POLYC 4 polys 1 weekly @ 150p per week Txt STOP 2 stop This msg free Stream 0871212025016
#
# your
#
# has
#
# or
#
# this
#
# ['tone', 'club', 'subs', 'now', 'expired', '2', 're', 'sub', 'reply', 'monoc', '4', 'monos', 'polyc', '4', 'polys', '1', 'weekly', '150p', 'per', 'week', 'txt', 'stop', '2', 'stop', 'msg', 'free', 'stream', '0871212025016']
#
# 28
#
# Hiya, probably coming home * weekend after next
#
# after
#
# ['hiya', 'probably', 'coming', 'home', 'weekend', 'next']
#
# 6
#
# Watch lor. I saw a few swatch one i thk quite ok. Ard 116 but i need 2nd opinion leh...
#
# i
#
# a
#
# i
#
# but
#
# ['watch', 'lor', 'saw', 'few', 'swatch', 'one', 'thk', 'quite', 'ok', 'ard', '116', 'i', 'need', '2nd', 'opinion', 'leh']
#
# 16
#
# great princess! I love giving and receiving oral. Doggy style is my fave position. How about you? I enjoy making love  &lt;#&gt;  times per night :)
#
# i
#
# and
#
# is
#
# how
#
# you
#
# ['great', 'princess', 'love', 'giving', 'receiving', 'oral', 'doggy', 'style', 'my', 'fave', 'position', 'about', 'i', 'enjoy', 'making', 'love', 'lt', 'gt', 'times', 'per', 'night']
#
# 21
#
# Sun ah... Thk mayb can if dun have anythin on... Thk have to book e lesson... E pilates is at orchard mrt u noe hor...
#
# can
#
# have
#
# on
#
# have
#
# is
#
# u
#
# ['sun', 'ah', 'thk', 'mayb', 'if', 'dun', 'anythin', 'thk', 'to', 'book', 'e', 'lesson', 'e', 'pilates', 'at', 'orchard', 'mrt', 'noe', 'hor']
#
# 19
#
# 'An Amazing Quote'' - "Sometimes in life its difficult to decide whats wrong!! a lie that brings a smile or the truth that brings a tear...."
#
# an
#
# in
#
# its
#
# to
#
# a
#
# that
#
# a
#
# or
#
# that
#
# a
#
# ['amazing', 'quote', 'sometimes', 'life', 'difficult', 'decide', 'whats', 'wrong', 'lie', 'brings', 'smile', 'the', 'truth', 'brings', 'tear']
#
# 15
#
# Awesome, text me when you're restocked
#
# me
#
# you
#
# ['awesome', 'text', 'when', 're', 'restocked']
#
# 5
#
# S:)8 min to go for lunch:)
#
# s
#
# to
#
# for
#
# ['8', 'min', 'go', 'lunch']
#
# 4
#
# Babe, have you got enough money to pick up bread and milk ? And I'll give you it back when you get home ?
#
# have
#
# to
#
# up
#
# and
#
# and
#
# you
#
# when
#
# ['babe', 'got', 'enough', 'money', 'pick', 'bread', 'milk', 'i', 'll', 'give', 'you', 'it', 'back', 'you', 'get', 'home']
#
# 16
#
# They are just making it easy to pay back. I have  &lt;#&gt; yrs to say but i can pay back earlier. You get?
#
# they
#
# just
#
# it
#
# to
#
# i
#
# to
#
# but
#
# can
#
# you
#
# ['are', 'making', 'easy', 'pay', 'back', 'have', 'lt', 'gt', 'yrs', 'say', 'i', 'pay', 'back', 'earlier', 'get']
#
# 15
#
# Actually nvm, got hella cash, we still on for  &lt;#&gt; ish?
#
# we
#
# on
#
# ['actually', 'nvm', 'got', 'hella', 'cash', 'still', 'for', 'lt', 'gt', 'ish']
#
# 10
#
# Just got part Nottingham - 3 hrs 63miles. Good thing i love my man so much, but only doing 40mph. Hey ho
#
# just
#
# i
#
# my
#
# so
#
# but
#
# doing
#
# ['got', 'part', 'nottingham', '3', 'hrs', '63miles', 'good', 'thing', 'love', 'man', 'much', 'only', '40mph', 'hey', 'ho']
#
# 15
#
# You have won a guaranteed Â£200 award or even Â£1000 cashto claim UR award call free on 08000407165 (18+) 2 stop getstop on 88222 PHP
#
# you
#
# a
#
# or
#
# ur
#
# on
#
# on
#
# ['have', 'won', 'guaranteed', 'â', '200', 'award', 'even', 'â', '1000', 'cashto', 'claim', 'award', 'call', 'free', '08000407165', '18+', '2', 'stop', 'getstop', '88222', 'php']
#
# 21
#
# I want to tell you how bad I feel that basically the only times I text you lately are when I need drugs
#
# i
#
# to
#
# you
#
# i
#
# that
#
# the
#
# i
#
# you
#
# are
#
# i
#
# ['want', 'tell', 'how', 'bad', 'feel', 'basically', 'only', 'times', 'text', 'lately', 'when', 'need', 'drugs']
#
# 13
#
# Please don't text me anymore. I have nothing else to say.
#
# don
#
# me
#
# i
#
# to
#
# ['please', 't', 'text', 'anymore', 'have', 'nothing', 'else', 'say']
#
# 8
#
# Congratulations ur awarded either Â£500 of CD gift vouchers & Free entry 2 our Â£100 weekly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16
#
# ur
#
# of
#
# our
#
# to
#
# ['congratulations', 'awarded', 'either', 'â', '500', 'cd', 'gift', 'vouchers', 'free', 'entry', '2', 'â', '100', 'weekly', 'draw', 'txt', 'music', '87066', 'tncs', 'www', 'ldew', 'com1win150ppmx3age16']
#
# 22
#
# How much are we getting?
#
# how
#
# are
#
# ['much', 'we', 'getting']
#
# 3
#
# I'm going 4 lunch now wif my family then aft dat i go str 2 orchard lor.
#
# i
#
# now
#
# my
#
# then
#
# i
#
# ['m', 'going', '4', 'lunch', 'wif', 'family', 'aft', 'dat', 'go', 'str', '2', 'orchard', 'lor']
#
# 13
#
# Sorry de i went to shop.
#
# i
#
# to
#
# ['sorry', 'de', 'went', 'shop']
#
# 4
#
# The LAY MAN! Just to let you know you are missed and thought off. Do have a great day. And if you can send me bimbo and ugo's numbers, ill appreciate. Safe
#
# the
#
# just
#
# you
#
# you
#
# and
#
# off
#
# have
#
# and
#
# you
#
# me
#
# and
#
# s
#
# ['lay', 'man', 'to', 'let', 'know', 'are', 'missed', 'thought', 'do', 'a', 'great', 'day', 'if', 'can', 'send', 'bimbo', 'ugo', 'numbers', 'ill', 'appreciate', 'safe']
#
# 21
#
# Had the money issue weigh me down but thanks to you, I can breathe easier now. I.ll make sure you dont regret it. Thanks.
#
# had
#
# me
#
# but
#
# to
#
# i
#
# now
#
# you
#
# it
#
# ['the', 'money', 'issue', 'weigh', 'down', 'thanks', 'can', 'breathe', 'easier', 'i', 'll', 'make', 'sure', 'you', 'dont', 'regret', 'thanks']
#
# 17
#
# "CHEERS U TEX MECAUSE U WEREBORED! YEAH OKDEN HUNNY R UIN WK SAT?SOUND'S LIKEYOUR HAVIN GR8FUN J! KEEP UPDAT COUNTINLOTS OF LOVEME XXXXX."
#
# u
#
# u
#
# s
#
# of
#
# ['cheers', 'tex', 'mecause', 'werebored', 'yeah', 'okden', 'hunny', 'r', 'uin', 'wk', 'sat', 'sound', 'likeyour', 'havin', 'gr8fun', 'j', 'keep', 'updat', 'countinlots', 'loveme', 'xxxxx']
#
# 21
#
# Tyler (getting an 8th) has to leave not long after 9, can you get here in like an hour?
#
# an
#
# has
#
# not
#
# after
#
# can
#
# here
#
# an
#
# ['tyler', 'getting', '8th', 'to', 'leave', 'long', '9', 'you', 'get', 'in', 'like', 'hour']
#
# 12
#
# Yun ah.now Ã¼ wkg where?btw if Ã¼ go nus sc. Ãœ wana specialise in wad?
#
# now
#
# where
#
# if
#
# in
#
# ['yun', 'ah', 'ã¼', 'wkg', 'btw', 'ã¼', 'go', 'nus', 'sc', 'ãœ', 'wana', 'specialise', 'wad']
#
# 13
#
# HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd, PO Box 1327 Croydon CR9 5WB 0870 is a national rate call
#
# now
#
# just
#
# is
#
# ['hot', 'live', 'fantasies', 'call', '08707509020', '20p', 'per', 'min', 'ntt', 'ltd', 'po', 'box', '1327', 'croydon', 'cr9', '5wb', '0870', 'a', 'national', 'rate', 'call']
#
# 21
#
# It doesnt make sense to take it there unless its free. If you need to know more, wikipedia.com
#
# it
#
# to
#
# it
#
# its
#
# if
#
# to
#
# more
#
# ['doesnt', 'make', 'sense', 'take', 'there', 'unless', 'free', 'you', 'need', 'know', 'wikipedia', 'com']
#
# 12
#
# Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile when sum1 Hurts U Smile becoz SOMEONE still Loves to see u Smiling!!
#
# in
#
# in
#
# when
#
# when
#
# u
#
# to
#
# u
#
# ['smile', 'pleasure', 'smile', 'pain', 'smile', 'trouble', 'pours', 'like', 'rain', 'smile', 'sum1', 'hurts', 'smile', 'becoz', 'someone', 'still', 'loves', 'see', 'smiling']
#
# 19
#
# Although i told u dat i'm into baig face watches now but i really like e watch u gave cos it's fr u. Thanx 4 everything dat u've done today, i'm touched...
#
# i
#
# u
#
# i
#
# into
#
# now
#
# i
#
# u
#
# it
#
# u
#
# u
#
# i
#
# ['although', 'told', 'dat', 'm', 'baig', 'face', 'watches', 'but', 'really', 'like', 'e', 'watch', 'gave', 'cos', 's', 'fr', 'thanx', '4', 'everything', 'dat', 've', 'done', 'today', 'm', 'touched']
#
# 25
#
# MMM ... Fuck .... Merry Christmas to me
#
# to
#
# ['mmm', 'fuck', 'merry', 'christmas', 'me']
#
# 5
#
# We're done...
#
# we
#
# ['re', 'done']
#
# 2
#
# Its a valentine game. . . Send dis msg to all ur friends. .. If 5 answers r d same then someone really loves u. Ques- which colour suits me the best?rply me
#
# its
#
# to
#
# ur
#
# if
#
# same
#
# u
#
# which
#
# me
#
# me
#
# ['a', 'valentine', 'game', 'send', 'dis', 'msg', 'all', 'friends', '5', 'answers', 'r', 'd', 'then', 'someone', 'really', 'loves', 'ques', 'colour', 'suits', 'the', 'best', 'rply']
#
# 22
#
# Cant believe i said so many things to you this morning when all i really wanted to say was good morning, i love you! Have a beautiful morning. See you in the library later.
#
# i
#
# so
#
# to
#
# this
#
# when
#
# i
#
# to
#
# was
#
# i
#
# you
#
# a
#
# you
#
# the
#
# ['cant', 'believe', 'said', 'many', 'things', 'morning', 'all', 'really', 'wanted', 'say', 'good', 'morning', 'love', 'have', 'beautiful', 'morning', 'see', 'you', 'in', 'library', 'later']
#
# 21
#
# And miss vday the parachute and double coins??? U must not know me very well...
#
# and
#
# the
#
# and
#
# u
#
# not
#
# me
#
# ['miss', 'vday', 'parachute', 'double', 'coins', 'must', 'know', 'very', 'well']
#
# 9
#
# Bugis oso near wat...
#
# ['bugis', 'oso', 'near', 'wat']
#
# 4
#
# No no. I will check all rooms befor activities
#
# no
#
# i
#
# all
#
# ['no', 'will', 'check', 'rooms', 'befor', 'activities']
#
# 6
#
# Y she dun believe leh? I tot i told her it's true already. I thk she muz c us tog then she believe.
#
# she
#
# i
#
# i
#
# her
#
# s
#
# i
#
# she
#
# then
#
# ...
#
# 30
#
# Mm you ask him to come its enough :-)
#
# you
#
# him
#
# its
#
# ['mm', 'ask', 'to', 'come', 'enough']
#
# 5
#
# Good afternoon, my boytoy ... How are you feeling today ? Better I hope? Are you being my good boy? Are you my obedient, slave? Do you please your Queen?
#
# my
#
# how
#
# you
#
# i
#
# are
#
# being
#
# are
#
# my
#
# do
#
# your
#
# ['good', 'afternoon', 'boytoy', 'feeling', 'today', 'better', 'hope', 'you', 'good', 'boy', 'are', 'you', 'my', 'obedient', 'slave', 'you', 'please', 'queen']
#
# 18
#
# U 447801259231 have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094597
#
# u
#
# have
#
# who
#
# with
#
# out
#
# they
#
# who
#
# ur
#
# on
#
# ['447801259231', 'a', 'secret', 'admirer', 'is', 'looking', '2', 'make', 'contact', 'u', 'find', 'r', 'reveal', 'who', 'thinks', 'so', 'special', 'call', '09058094597']
#
# 19
#
# I love ya too but try and budget your money better babe. Gary would freak on me if he knew
#
# i
#
# too
#
# and
#
# your
#
# on
#
# if
#
# ['love', 'ya', 'but', 'try', 'budget', 'money', 'better', 'babe', 'gary', 'would', 'freak', 'me', 'he', 'knew']
#
# 14
#
# Thk some of em find wtc too far... Weiyi not goin... E rest i dunno yet... R ur goin 4 dinner den i might b able to join...
#
# some
#
# too
#
# not
#
# i
#
# ur
#
# i
#
# to
#
# ['thk', 'of', 'em', 'find', 'wtc', 'far', 'weiyi', 'goin', 'e', 'rest', 'dunno', 'yet', 'r', 'goin', '4', 'dinner', 'den', 'might', 'b', 'able', 'join']
#
# 21
#
# You have got tallent but you are wasting.
#
# you
#
# but
#
# are
#
# ['have', 'got', 'tallent', 'you', 'wasting']
#
# 5
#
# Frnd s not juz a word.....not merely a relationship.....its a silent promise which says ... " I will be with YOU " Wherevr.. Whenevr.. Forevr... Gudnyt dear..
#
# s
#
# a
#
# not
#
# a
#
# its
#
# which
#
# i
#
# be
#
# you
#
# ['frnd', 'juz', 'word', 'not', 'merely', 'relationship', 'a', 'silent', 'promise', 'says', 'will', 'with', 'wherevr', 'whenevr', 'forevr', 'gudnyt', 'dear']
#
# 17
#
# No. She's currently in scotland for that.
#
# no
#
# s
#
# in
#
# for
#
# ['she', 'currently', 'scotland', 'that']
#
# 4
#
# Exactly. Anyways how far. Is jide her to study or just visiting
#
# how
#
# is
#
# her
#
# or
#
# ['exactly', 'anyways', 'far', 'jide', 'to', 'study', 'just', 'visiting']
#
# 8
#
# I'm e person who's doing e sms survey...
#
# i
#
# who
#
# doing
#
# ['m', 'e', 'person', 's', 'e', 'sms', 'survey']
#
# 7
#
# NEFT Transaction with reference number  &lt;#&gt;  for Rs. &lt;DECIMAL&gt;  has been credited to the beneficiary account on  &lt;#&gt;  at  &lt;TIME&gt; : &lt;#&gt;
#
# with
#
# for
#
# has
#
# to
#
# on
#
# at
#
# ['neft', 'transaction', 'reference', 'number', 'lt', 'gt', 'rs', 'lt', 'decimal', 'gt', 'been', 'credited', 'the', 'beneficiary', 'account', 'lt', 'gt', 'lt', 'time', 'gt', 'lt', 'gt']
#
# 22
#
# Then. You are eldest know.
#
# then
#
# are
#
# ['you', 'eldest', 'know']
#
# 3
#
# When people see my msgs, They think Iam addicted to msging... They are wrong, Bcoz They don\'t know that Iam addicted to my sweet Friends..!! BSLVYL
#
# when
#
# my
#
# they
#
# to
#
# they
#
# they
#
# t
#
# that
#
# to
#
# ['people', 'see', 'msgs', 'think', 'iam', 'addicted', 'msging', 'are', 'wrong', 'bcoz', 'don', 'know', 'iam', 'addicted', 'my', 'sweet', 'friends', 'bslvyl']
#
# 18
#
# Wat time Ã¼ finish?
#
# ['wat', 'time', 'ã¼', 'finish']
#
# 4
#
# I thought slide is enough.
#
# i
#
# is
#
# ['thought', 'slide', 'enough']
#
# 3
#
# Sos! Any amount i can get pls.
#
# any
#
# i
#
# ['sos', 'amount', 'can', 'get', 'pls']
#
# 5
#
# URGENT!! Your 4* Costa Del Sol Holiday or Â£5000 await collection. Call 09050090044 Now toClaim. SAE, TC s, POBox334, Stockport, SK38xh, CostÂ£1.50/pm, Max10mins
#
# your
#
# or
#
# now
#
# s
#
# ['urgent', '4', 'costa', 'del', 'sol', 'holiday', 'â', '5000', 'await', 'collection', 'call', '09050090044', 'toclaim', 'sae', 'tc', 'pobox334', 'stockport', 'sk38xh', 'costâ', '1', '50', 'pm', 'max10mins']
#
# 23
#
# Just finished. Missing you plenty
#
# just
#
# you
#
# ['finished', 'missing', 'plenty']
#
# 3
#
# I have printed it oh. So  &lt;#&gt;  come upstairs
#
# i
#
# it
#
# so
#
# ['have', 'printed', 'oh', 'lt', 'gt', 'come', 'upstairs']
#
# 7
#
# LOL that would be awesome payback.
#
# that
#
# be
#
# ['lol', 'would', 'awesome', 'payback']
#
# 4
#
# Cool, we shall go and see, have to go to tip anyway. Are you at home, got something to drop in later? So lets go to town tonight! Maybe mum can take us in.
#
# we
#
# and
#
# have
#
# to
#
# are
#
# at
#
# to
#
# in
#
# so
#
# to
#
# can
#
# in
#
# ['cool', 'shall', 'go', 'see', 'go', 'tip', 'anyway', 'you', 'home', 'got', 'something', 'drop', 'later', 'lets', 'go', 'to', 'town', 'tonight', 'maybe', 'mum', 'take', 'us']
#
# 22
#
# Not yet chikku..wat abt u?
#
# not
#
# u
#
# ['yet', 'chikku', 'wat', 'abt']
#
# 4
#
# Hey darlin.. i can pick u up at college if u tell me wen & where 2 mt.. love Pete xx
#
# i
#
# u
#
# at
#
# if
#
# me
#
# where
#
# ['hey', 'darlin', 'can', 'pick', 'up', 'college', 'u', 'tell', 'wen', '2', 'mt', 'love', 'pete', 'xx']
#
# 14
#
# FREE for 1st week! No1 Nokia tone 4 ur mob every week just txt NOKIA to 87077 Get txting and tell ur mates. zed POBox 36504 W45WQ norm150p/tone 16+
#
# for
#
# ur
#
# just
#
# to
#
# and
#
# ur
#
# ['free', '1st', 'week', 'no1', 'nokia', 'tone', '4', 'mob', 'every', 'week', 'txt', 'nokia', '87077', 'get', 'txting', 'tell', 'mates', 'zed', 'pobox', '36504', 'w45wq', 'norm150p', 'tone', '16+']
#
# 24
#
# Its like that hotel dusk game i think. You solve puzzles in a area thing
#
# its
#
# that
#
# i
#
# you
#
# in
#
# ['like', 'hotel', 'dusk', 'game', 'think', 'solve', 'puzzles', 'a', 'area', 'thing']
#
# 10
#
# K..then come wenever u lik to come and also tel vikky to come by getting free time..:-)
#
# then
#
# u
#
# to
#
# and
#
# to
#
# by
#
# ['k', 'come', 'wenever', 'lik', 'come', 'also', 'tel', 'vikky', 'come', 'getting', 'free', 'time']
#
# 12
#
# One of the joys in lifeis waking up each daywith thoughts that somewhereSomeone cares enough tosend a warm morning greeting.. -
#
# of
#
# in
#
# up
#
# that
#
# a
#
# ['one', 'the', 'joys', 'lifeis', 'waking', 'each', 'daywith', 'thoughts', 'somewheresomeone', 'cares', 'enough', 'tosend', 'warm', 'morning', 'greeting']
#
# 15
#
# No dice, art class 6 thru 9 :( thanks though. Any idea what time I should come tomorrow?
#
# no
#
# any
#
# what
#
# i
#
# ['dice', 'art', 'class', '6', 'thru', '9', 'thanks', 'though', 'idea', 'time', 'should', 'come', 'tomorrow']
#
# 13
#
# Wishing you and your family Merry "X" mas and HAPPY NEW Year in advance..
#
# you
#
# your
#
# and
#
# in
#
# ['wishing', 'family', 'merry', 'x', 'mas', 'and', 'happy', 'new', 'year', 'advance']
#
# 10
#
# Hard LIVE 121 chat just 60p/min. Choose your girl and connect LIVE. Call 09094646899 now! Cheap Chat UK's biggest live service. VU BCM1896WC1N3XX
#
# just
#
# your
#
# and
#
# now
#
# s
#
# ['hard', 'live', '121', 'chat', '60p', 'min', 'choose', 'girl', 'connect', 'live', 'call', '09094646899', 'cheap', 'chat', 'uk', 'biggest', 'live', 'service', 'vu', 'bcm1896wc1n3xx']
#
# 20
#
# In fact when do you leave? I think addie goes back to school tues or wed
#
# in
#
# when
#
# you
#
# i
#
# to
#
# or
#
# ['fact', 'do', 'leave', 'think', 'addie', 'goes', 'back', 'school', 'tues', 'wed']
#
# 10
#
# Mum not going robinson already.
#
# not
#
# ['mum', 'going', 'robinson', 'already']
#
# 4
#
# You'll never believe this but i have actually got off at taunton. Wow
#
# you
#
# this
#
# i
#
# off
#
# ['ll', 'never', 'believe', 'but', 'have', 'actually', 'got', 'at', 'taunton', 'wow']
#
# 10
#
# If u laugh really loud.. If u talk spontaneously.. If u dont care what others feel.. U are probably with your dear &amp; best friends.. GOODEVENING Dear..:)
#
# if
#
# if
#
# if
#
# what
#
# u
#
# with
#
# ['laugh', 'really', 'loud', 'u', 'talk', 'spontaneously', 'u', 'dont', 'care', 'others', 'feel', 'u', 'are', 'probably', 'your', 'dear', 'amp', 'best', 'friends', 'goodevening', 'dear']
#
# 21
#
# Why must we sit around and wait for summer days to celebrate. Such a magical sight when the worlds dressed in white. Oooooh let there be snow.
#
# why
#
# we
#
# and
#
# for
#
# to
#
# such
#
# when
#
# in
#
# there
#
# ['must', 'sit', 'around', 'wait', 'summer', 'days', 'celebrate', 'a', 'magical', 'sight', 'the', 'worlds', 'dressed', 'white', 'oooooh', 'let', 'be', 'snow']
#
# 18
#
# Urgent! call 09066350750 from your landline. Your complimentary 4* Ibiza Holiday or 10,000 cash await collection SAE T&Cs PO BOX 434 SK3 8WP 150 ppm 18+
#
# from
#
# your
#
# or
#
# t
#
# ['urgent', 'call', '09066350750', 'landline', 'your', 'complimentary', '4', 'ibiza', 'holiday', '10', '000', 'cash', 'await', 'collection', 'sae', 'cs', 'po', 'box', '434', 'sk3', '8wp', '150', 'ppm', '18+']
#
# 24
#
# Yup i thk cine is better cos no need 2 go down 2 plaza mah.
#
# i
#
# is
#
# no
#
# down
#
# ['yup', 'thk', 'cine', 'better', 'cos', 'need', '2', 'go', '2', 'plaza', 'mah']
#
# 11
#
# No you'll just get a headache trying to figure it out. U can trust me to do the math. I promise. O:-)
#
# no
#
# just
#
# a
#
# to
#
# it
#
# u
#
# me
#
# do
#
# i
#
# ['you', 'll', 'get', 'headache', 'trying', 'figure', 'out', 'can', 'trust', 'to', 'the', 'math', 'promise', 'o']
#
# 14
#
# God picked up a flower and dippeditinaDEW, lovingly touched itwhichturnedinto u, and the he gifted tomeandsaid,THIS FRIEND IS 4U
#
# up
#
# and
#
# u
#
# the
#
# this
#
# is
#
# ['god', 'picked', 'a', 'flower', 'dippeditinadew', 'lovingly', 'touched', 'itwhichturnedinto', 'and', 'he', 'gifted', 'tomeandsaid', 'friend', '4u']
#
# 14
#
# At home by the way
#
# at
#
# by
#
# ['home', 'the', 'way']
#
# 3
#
# Ha ha cool cool chikku chikku:-):-DB-)
#
# ['ha', 'ha', 'cool', 'cool', 'chikku', 'chikku', 'db']
#
# 7
#
# Yes. that will be fine. Love you. Be safe.
#
# that
#
# be
#
# you
#
# ['yes', 'will', 'fine', 'love', 'be', 'safe']
#
# 6
#
# Customer place i will call you.
#
# i
#
# you
#
# ['customer', 'place', 'will', 'call']
#
# 4
#
# I'm in solihull, | do you want anything?
#
# i
#
# in
#
# do
#
# ['m', 'solihull', '|', 'you', 'want', 'anything']
#
# 6
#
# True. Its easier with her here.
#
# its
#
# with
#
# here
#
# ['true', 'easier', 'her']
#
# 3
#
# Am new 2 club & dont fink we met yet Will B gr8 2 C U Please leave msg 2day wiv ur area 09099726553 reply promised CARLIE x CallsÂ£1/minMobsmore LKPOBOX177HP51FL
#
# am
#
# we
#
# will
#
# u
#
# ur
#
# ['new', '2', 'club', 'dont', 'fink', 'met', 'yet', 'b', 'gr8', '2', 'c', 'please', 'leave', 'msg', '2day', 'wiv', 'area', '09099726553', 'reply', 'promised', 'carlie', 'x', 'callsâ', '1', 'minmobsmore', 'lkpobox177hp51fl']
#
# 26
#
# Please reserve ticket on saturday eve from chennai to thirunelvali and again from tirunelvali to chennai on sunday eve...i already see in net..no ticket available..i want to book ticket through tackle ..
#
# on
#
# from
#
# to
#
# and
#
# from
#
# to
#
# on
#
# i
#
# in
#
# no
#
# i
#
# to
#
# through
#
# ['please', 'reserve', 'ticket', 'saturday', 'eve', 'chennai', 'thirunelvali', 'again', 'tirunelvali', 'chennai', 'sunday', 'eve', 'already', 'see', 'net', 'ticket', 'available', 'want', 'book', 'ticket', 'tackle']
#
# 21
#
# Anytime...
#
# ['anytime']
#
# 1
#
# Sad story of a Man - Last week was my b'day. My Wife did'nt wish me. My Parents forgot n so did my Kids . I went to work. Even my Colleagues did not wish. As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there. She said,'' do u mind if I go into the bedroom for a minute ? '' ''OK'', I sed in a sexy mood. She came out 5 minuts latr wid a cake...n My Wife, My Parents, My Kidz, My Friends n My Colleagues. All screaming.. SURPRISE !! and I was waiting on the sofa.. ... ..... ' NAKED...!
#
# of
#
# was
#
# my
#
# did
#
# me
#
# so
#
# my
#
# i
#
# to
#
# my
#
# did
#
# as
#
# my
#
# my
#
# i
#
# she
#
# me
#
# after
#
# she
#
# me
#
# her
#
# we
#
# there
#
# do
#
# if
#
# into
#
# for
#
# i
#
# in
#
# she
#
# out
#
# a
#
# my
#
# my
#
# my
#
# my
#
# my
#
# all
#
# and
#
# was
#
# on
#
# ['sad', 'story', 'man', 'last', 'week', 'b', 'day', 'wife', 'nt', 'wish', 'parents', 'forgot', 'n', 'kids', 'went', 'work', 'even', 'colleagues', 'did', 'not', 'wish', 'entered', 'cabin', 'pa', 'said', 'happy', 'b', 'day', 'boss', 'felt', 'special', 'askd', '4', 'lunch', 'lunch', 'invited', 'to', 'apartment', 'went', 'said', 'u', 'mind', 'i', 'go', 'the', 'bedroom', 'a', 'minute', 'ok', 'i', 'sed', 'a', 'sexy', 'mood', 'she', 'came', '5', 'minuts', 'latr', 'wid', 'a', 'cake', 'n', 'wife', 'parents', 'kidz', 'my', 'friends', 'n', 'my', 'colleagues', 'screaming', 'surprise', 'i', 'waiting', 'the', 'sofa', 'naked']
#
# 78
#
# U 2.
#
# u
#
# ['2']
#
# 1
#
# Yup no more already... Thanx 4 printing n handing it up.
#
# no
#
# it
#
# ['yup', 'more', 'already', 'thanx', '4', 'printing', 'n', 'handing', 'up']
#
# 9
#
# This msg is for your mobile content order It has been resent as previous attempt failed due to network error Queries to customersqueries@netvision.uk.com
#
# this
#
# is
#
# your
#
# it
#
# been
#
# as
#
# to
#
# to
#
# ['msg', 'for', 'mobile', 'content', 'order', 'has', 'resent', 'previous', 'attempt', 'failed', 'due', 'network', 'error', 'queries', 'customersqueries', 'netvision', 'uk', 'com']
#
# 18
#
# I'm done...
#
# i
#
# ['m', 'done']
#
# 2
#
# Sorry, I'll call later
#
# i
#
# ['sorry', 'll', 'call', 'later']
#
# 4
#
# Sorry, I'll call later
#
# i
#
# ['sorry', 'll', 'call', 'later']
#
# 4
#
# Camera - You are awarded a SiPix Digital Camera! call 09061221066 fromm landline. Delivery within 28 days.
#
# you
#
# a
#
# ['camera', 'are', 'awarded', 'sipix', 'digital', 'camera', 'call', '09061221066', 'fromm', 'landline', 'delivery', 'within', '28', 'days']
#
# 14
#
# No..its ful of song lyrics..
#
# no
#
# of
#
# ['its', 'ful', 'song', 'lyrics']
#
# 4
#
# Babe! How goes that day ? What are you up to ? I miss you already, my Love ... * loving kiss* ... I hope everything goes well.
#
# how
#
# that
#
# what
#
# you
#
# to
#
# you
#
# my
#
# i
#
# ['babe', 'goes', 'day', 'are', 'up', 'miss', 'already', 'love', 'loving', 'kiss', 'i', 'hope', 'everything', 'goes', 'well']
#
# 15
#
# Dunno lei shd b driving lor cos i go sch 1 hr oni.
#
# i
#
# ['dunno', 'lei', 'shd', 'b', 'driving', 'lor', 'cos', 'go', 'sch', '1', 'hr', 'oni']
#
# 12
#
# Bring home some Wendy =D
#
# some
#
# ['bring', 'home', 'wendy', '=d']
#
# 4
#
# 1's reach home call me.
#
# s
#
# me
#
# ['1', 'reach', 'home', 'call']
#
# 4
#
# U're welcome... Caught u using broken english again...
#
# u
#
# u
#
# again
#
# ['re', 'welcome', 'caught', 'using', 'broken', 'english']
#
# 6
#
# How is it possible to teach you. And where.
#
# how
#
# it
#
# to
#
# you
#
# where
#
# ['is', 'possible', 'teach', 'and']
#
# 4
#
# She said,'' do u mind if I go into the bedroom for a minute ? '' ''OK'', I sed in a sexy mood. She came out 5 minuts latr wid a cake...n My Wife,
#
# she
#
# do
#
# if
#
# into
#
# for
#
# i
#
# in
#
# she
#
# out
#
# a
#
# my
#
# ['said', 'u', 'mind', 'go', 'the', 'bedroom', 'minute', 'ok', 'i', 'sed', 'a', 'sexy', 'mood', 'came', '5', 'minuts', 'latr', 'wid', 'a', 'cake', 'n', 'wife']
#
# 22
#
# Excellent! Are you ready to moan and scream in ecstasy?
#
# are
#
# to
#
# and
#
# in
#
# ['excellent', 'you', 'ready', 'moan', 'scream', 'ecstasy']
#
# 6
#
# Hmm...Bad news...Hype park plaza $700 studio taken...Only left 2 bedrm-$900...
#
# only
#
# ['hmm', 'bad', 'news', 'hype', 'park', 'plaza', '700', 'studio', 'taken', 'left', '2', 'bedrm', '900']
#
# 13
#
# Can't. I feel nauseous. I'm so pissed. I didn't eat any sweets all week cause today I was planning to pig out. I was dieting all week. And now I'm not hungry :/
#
# can
#
# i
#
# i
#
# so
#
# i
#
# t
#
# any
#
# all
#
# i
#
# to
#
# out
#
# was
#
# all
#
# and
#
# i
#
# not
#
# ['feel', 'nauseous', 'm', 'pissed', 'didn', 't', 'eat', 'sweets', 'week', 'cause', 'today', 'planning', 'pig', 'was', 'dieting', 'week', 'now', 'i', 'm', 'hungry']
#
# 20
#
# Guai... Ãœ shd haf seen him when he's naughty... Ãœ so free today? Can go jogging...
#
# him
#
# he
#
# so
#
# can
#
# ['guai', 'ãœ', 'shd', 'haf', 'seen', 'when', 's', 'naughty', 'ãœ', 'free', 'today', 'go', 'jogging']
#
# 13
#
# S.this will increase the chance of winning.
#
# s
#
# will
#
# the
#
# of
#
# ['this', 'increase', 'chance', 'winning']
#
# 4
#
# Hi im having the most relaxing time ever! we have to get up at 7am every day! was the party good the other night? I get home tomorrow at 5ish.
#
# having
#
# most
#
# we
#
# to
#
# up
#
# was
#
# the
#
# i
#
# at
#
# ['hi', 'im', 'relaxing', 'time', 'ever', 'have', 'get', '7am', 'every', 'day', 'the', 'party', 'good', 'the', 'other', 'night', 'get', 'home', 'tomorrow', 'at', '5ish']
#
# 21
